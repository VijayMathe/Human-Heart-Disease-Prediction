# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dataset_1.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63    1   3       145   233    1        0      150      0      2.3
# 1      37    1   2       130   250    0        1      187      0      3.5
# 2      41    0   1       130   204    0        0      172      0      1.4
# 3      56    1   1       120   236    0        1      178      0      0.8
# 4      57    0   0       120   354    0        1      163      1      0.6
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 2419   57    0   0       140   241    0        1      123      1      0.2
# 2420   45    1   3       110   264    0        1      132      0      1.2
# 2421   68    1   0       144   193    1        1      141      0      3.4
# 2422   57    1   0       130   131    0        1      115      1      1.2
# 2423   57    0   1       130   236    0        0      174      0      0.0
#
#       slope  ca  thal  target
# 0         0   0     1       1
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  2424.000000  2424.000000  2424.000000  2424.000000  2424.000000
# mean     54.366337     0.683168     0.966997   131.623762   246.264026
# std       9.068972     0.465337     1.030561    17.512791    51.755828
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      47.000000     0.000000     0.000000   120.000000   211.000000
# 50%      55.000000     1.000000     1.000000   130.000000   240.000000
# 75%      61.000000     1.000000     2.000000   140.000000   275.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  2424.000000  2424.000000  2424.000000  2424.000000  2424.000000
# mean      0.148515     0.528053   149.646865     0.326733     1.039604
# std       0.355683     0.525099    22.872051     0.469115     1.159397
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2424 non-null   int64
#  1   sex       2424 non-null   int64
#  2   cp        2424 non-null   int64
#  3   trestbps  2424 non-null   int64
#  4   chol      2424 non-null   int64
#  5   fbs       2424 non-null   int64
#  6   restecg   2424 non-null   int64
#  7   thalach   2424 non-null   int64
#  8   exang     2424 non-null   int64
#  9   oldpeak   2424 non-null   float64
#  10  slope     2424 non-null   int64
#  11  ca        2424 non-null   int64
#  12  thal      2424 non-null   int64
#  13  target    2424 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 265.2 KB

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.style.use('seaborn')
df.hist(bins = 20, figsize=(20, 20))
plt.show()
# Out:
# /tmp/ipykernel_1427/2458022494.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
percentage = df['target'].value_counts(normalize = True)*100

# %%
resultslabels = ["Having Cancer", "Not having Cancer"]
plt.figure(figsize=(12, 7))
plt.pie(percentage, labels=resultslabels, autopct='%1.1f%%')
plt.title("Percentage Classification")
plt.show()

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df['target'], color='red')
# Out:
# <Axes: ylabel='target'>
